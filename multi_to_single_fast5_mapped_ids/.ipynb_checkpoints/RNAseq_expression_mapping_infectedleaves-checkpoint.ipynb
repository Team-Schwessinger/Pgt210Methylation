# %% [markdown]
# Mapping RNAseq reads with Salmon
# Input:
# * transcript reference
# * paired end fastq files
#
# Output:
# * one folder per pair end fastqs

# %%
import os

# %%
OUT_DIR = '../../analyses/genes_expression/'
FASTQ_DIR = '../../data/expression_data/'
reference_fn = '../../data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa'
salmon_exc = '../../../anaconda3/downloads/salmon-latest_linux_x86_64/bin/salmon'

# %%
OUT_DIR = os.path.abspath(OUT_DIR)
FASTQ_DIR = os.path.abspath(FASTQ_DIR)
reference_fn = os.path.abspath(reference_fn)
salmon_exc = os.path.abspath(salmon_exc)

# %%
# !ls {FASTQ_DIR}
# Out:
# Nmu_210_HSRNA_1_CCGTCC_L005_R1_001_val_1.fq.gz	RW2I3.fastq.gz
# Nmu_210_HSRNA_1_CCGTCC_L005_R2_001_val_2.fq.gz	RW3I1.fastq.gz
# Nmu_210_HSRNA_2_GTCCGC_L005_R1_001_val_1.fq.gz	RW3I2.fastq.gz
# Nmu_210_HSRNA_2_GTCCGC_L005_R2_001_val_2.fq.gz	RW3I3.fastq.gz
# Nmu_210_HSRNA_3_GTGAAA_L005_R1_001_val_1.fq.gz	RW4I1.fastq.gz
# Nmu_210_HSRNA_3_GTGAAA_L005_R2_001_val_2.fq.gz	RW4I2.fastq.gz
# NMu_PGTGS_1_AGTCAA_L005_R1_001_val_1.fq.gz	RW4I3.fastq.gz
# NMu_PGTGS_1_AGTCAA_L005_R2_001_val_2.fq.gz	RW5I1.fastq.gz
# Nmu_PGTGS_2_AGTTCC_L005_R1_001_val_1.fq.gz	RW5I2.fastq.gz
# Nmu_PGTGS_2_AGTTCC_L005_R2_001_val_2.fq.gz	RW5I3.fastq.gz
# Nmu_PGTGS_3_ATGTCA_L005_R1_001_val_1.fq.gz	RW6I1.fastq.gz
# Nmu_PGTGS_3_ATGTCA_L005_R2_001_val_2.fq.gz	RW6I2.fastq.gz
# RW0U1.fastq.gz					RW6I3.fastq.gz
# RW0U2.fastq.gz					RW7I1.fastq.gz
# RW0U3.fastq.gz					RW7I2.fastq.gz
# RW2I1.fastq.gz					RW7I3.fastq.gz
# RW2I2.fastq.gz

# %%
#index reference
# !{salmon_exc} version
# Out:
# Version Info:   This is the most recent version of salmon.
# salmon v1.1.0
#
# Usage:  salmon -h|--help or
#         salmon -v|--version or
#         salmon -c|--cite or
#         salmon [--no-version-check] <COMMAND> [-h | options]
#
# Commands:
#      index Create a salmon index
#      quant Quantify a sample
#      alevin single cell analysis
#      swim  Perform super-secret operation
#      quantmerge Merge multiple quantifications into a single file

# %%
salmon_index = reference_fn.replace('.fa', '.fa.salmon.index')

# %%
# !{salmon_exc} index -t {reference_fn} -i {salmon_index}
# Out:
# Version Info:   This is the most recent version of salmon.
# [2020-03-04 16:47:52.741] [jLog] [info] building index
# out : /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index
# [2020-03-04 16:47:52.741] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
#
# [2020-03-04 16:47:54.858] [puff::index::jointLog] [warning] Removed 865 transcripts that were sequence duplicates of indexed transcripts.
# [2020-03-04 16:47:54.858] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2020-03-04 16:47:54.871] [puff::index::jointLog] [info] Replaced 0 non-ATCG nucleotides
# [2020-03-04 16:47:54.871] [puff::index::jointLog] [info] Clipped poly-A tails from 3 transcripts
# wrote 37708 cleaned references
# seqHash 256 : 4b493e62e5ef2100006929ddbddb10797cdcce002881460adddcd2f29305dfac
# seqHash 512 : 3890c90844f7a584ceb5ca6eee5645b9f99d21d4c8e2f1a5c0a007221134dfb3a84f9387e8a6a7faee30bd3979fc5c9c13db5635a230515de9d8e972d7bf026b
# nameHash 256 : fcd946308dc8c13ffa7281521c20d5f8de79e2e8b4a5f3970639ccfe8ceb057e
# nameHash 512 : 11474aad28f2d7e996e41e3b8da1006ba3400b0b2081b63201490e24d94409fa549a9ea5b5542ffba333bf3833a832cb6a4bf9218e2018088bbd3fed2d85eecc
# [2020-03-04 16:47:55.047] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2020-03-04 16:47:55.634] [puff::index::jointLog] [info] ntHll estimated 33117769 distinct k-mers, setting filter size to 2^30
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 1073741824
# Capacity = 2
# Files:
# /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:1073741824
# Pass	Filling	Filtering
# 1	10	31
# 2	2	0
# True junctions count = 347781
# False junctions count = 384513
# Hash table size = 732294
# Candidate marks count = 1427788
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 980099
# Edges construction time: 11
# --------------------------------------------------------------------------------
# Distinct junctions = 347781
#
# approximateContigTotalLength: 24467393
# counters:
# 5142 171 134 6
# contig count: 538160 element count: 49426316 complex nodes: 5453
# size: 49426316
# # of ones in rank vector: 538159
# size: 49426316
# [2020-03-04 16:48:55.553] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index
# size = 49426316
# -----------------------------------------
# | Loading contigs | Time = 14.284 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading contig boundaries | Time = 4.0188 ms
# -----------------------------------------
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# [2020-03-04 16:48:55.796] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2020-03-04 16:48:55.978] [puff::index::jointLog] [info] contig count for validation: 538159
# [2020-03-04 16:48:56.084] [puff::index::jointLog] [info] Total # of Contigs : 538,159
# [2020-03-04 16:48:56.084] [puff::index::jointLog] [info] Total # of numerical Contigs : 538,159
# [2020-03-04 16:48:56.528] [puff::index::jointLog] [info]
# Total # of segments we have position for : 538,159
# [2020-03-04 16:48:56.554] [puff::index::jointLog] [info] total contig vec entries 957,684
# [2020-03-04 16:48:56.554] [puff::index::jointLog] [info] bits per offset entry 20
# [2020-03-04 16:48:56.886] [puff::index::jointLog] [info] there were 88,686  equivalence classes
# [2020-03-04 16:48:57.065] [puff::index::jointLog] [info] # segments = 538,159
# [2020-03-04 16:48:57.065] [puff::index::jointLog] [info] total length = 49,426,316
# [2020-03-04 16:48:57.081] [puff::index::jointLog] [info] Reading the reference files ...
# [2020-03-04 16:48:57.532] [puff::index::jointLog] [info] positional integer width = 26
# [2020-03-04 16:48:57.541] [puff::index::jointLog] [info] seqSize = 49,426,316
# [2020-03-04 16:48:57.541] [puff::index::jointLog] [info] rankSize = 49,426,316
# [2020-03-04 16:48:57.541] [puff::index::jointLog] [info] edgeVecSize = 0
# [2020-03-04 16:48:57.541] [puff::index::jointLog] [info] num keys = 33,281,546
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  99.9 %   elapsed:   0 min 5  sec   remaining:   0 min 0  sec
# Bitarray       174390272  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# [2020-03-04 16:49:02.285] [puff::index::jointLog] [info] mphf size = 20.7889 MB
# [2020-03-04 16:49:02.285] [puff::index::jointLog] [info] chunk size = 24,713,158
# [2020-03-04 16:49:02.285] [puff::index::jointLog] [info] chunk 0 = [0, 24,713,158)
# [2020-03-04 16:49:02.285] [puff::index::jointLog] [info] chunk 1 = [24,713,158, 49,426,286)
# [2020-03-04 16:49:07.875] [puff::index::jointLog] [info] finished populating pos vector
# [2020-03-04 16:49:07.875] [puff::index::jointLog] [info] writing index components
# [2020-03-04 16:49:08.121] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2020-03-04 16:49:08.209] [jLog] [info] done building index

# %%
fastq_fn_list = [os.path.join(FASTQ_DIR, x) for x in os.listdir(FASTQ_DIR)]

# %%
fastq_fn_list.sort()

# %%
#for paired end reads
for n in range(0, len(fastq_fn_list), 2):
    if "_" in os.path.basename(fastq_fn_list[n]):
    #do haustoria
        if os.path.basename(fastq_fn_list[n]).split("_")[2] == 'HSRNA':
            print(fastq_fn_list[n])
            print(fastq_fn_list[n + 1])
            #generate outfolder for each haustoria replicate
            QUANT_OUT = os.path.join(OUT_DIR, 'quant', \
                    os.path.basename(fastq_fn_list[n].split('.')[0]))
            if not os.path.exists(QUANT_OUT):
                os.makedirs(QUANT_OUT)
            # !{salmon_exc} quant -i {salmon_index} -l A -1 {fastq_fn_list[n]} -2 {fastq_fn_list[n + 1]} -p 8 --validateMappings -o {QUANT_OUT}
# Out:
# /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_1_CCGTCC_L005_R1_001_val_1.fq.gz
# /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_1_CCGTCC_L005_R2_001_val_2.fq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ mates1 ] => { /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_1_CCGTCC_L005_R1_001_val_1.fq.gz }
# ### [ mates2 ] => { /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_1_CCGTCC_L005_R2_001_val_2.fq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/Nmu_210_HSRNA_1_CCGTCC_L005_R1_001_val_1 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/Nmu_210_HSRNA_1_CCGTCC_L005_R1_001_val_1/logs
# [2020-03-04 14:05:10.187] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 14:05:10.187] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 14:05:10.187] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 14:05:10.187] [jointLog] [info] parsing read library format
# [2020-03-04 14:05:10.187] [jointLog] [info] There is 1 library.
# [2020-03-04 14:05:10.317] [jointLog] [info] Loading pufferfish index
# [2020-03-04 14:05:10.323] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 108.82 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.2412 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 138.2 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 113.91 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 129.6 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 8.8567 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 243.09 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 9.7538 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 278.57 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 14:05:10.969] [jointLog] [info] done
# [2020-03-04 14:05:10.969] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 14:05:10.983] [jointLog] [info] Number of decoys : 0
# [2020-03-04 14:05:12.364] [jointLog] [info] Automatically detected most likely library type as IU
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,001 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,001 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,002 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# hits: 9,934,174, hits per frag:  0.382097
#
#
#
#
#
#
#
#
#
# [2020-03-04 14:07:47.132] [jointLog] [info] Computed 76,625 rich equivalence classes for further processing
# [2020-03-04 14:07:47.132] [jointLog] [info] Counted 6,018,960 total reads in the equivalence classes
# [2020-03-04 14:07:47.135] [jointLog] [warning] 0.0158976% of fragments were shorter than the k used to build the index.
# If this fraction is too large, consider re-building the index with a smaller k.
# The minimum read size found was 20.
#
#
# [2020-03-04 14:07:47.135] [jointLog] [info] Number of mappings discarded because of alignment score : 57,018,179
# [2020-03-04 14:07:47.135] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 778,461
# [2020-03-04 14:07:47.135] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2020-03-04 14:07:47.135] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 27,537
# [2020-03-04 14:07:47.135] [jointLog] [info] Mapping rate = 22.8043%
#
# [2020-03-04 14:07:47.135] [jointLog] [info] finished quantifyLibrary()
# [2020-03-04 14:07:47.135] [jointLog] [info] Starting optimizer
# [2020-03-04 14:07:47.154] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2020-03-04 14:07:47.157] [jointLog] [info] iteration = 0 | max rel diff. = 13608
# [2020-03-04 14:07:47.541] [jointLog] [info] iteration = 100 | max rel diff. = 18.706
# [2020-03-04 14:07:48.114] [jointLog] [info] iteration = 200 | max rel diff. = 0.33462
# [2020-03-04 14:07:48.447] [jointLog] [info] iteration = 264 | max rel diff. = 0.00913723
# [2020-03-04 14:07:48.448] [jointLog] [info] Finished optimizer
# [2020-03-04 14:07:48.448] [jointLog] [info] writing output
#
# /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_2_GTCCGC_L005_R1_001_val_1.fq.gz
# /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_2_GTCCGC_L005_R2_001_val_2.fq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ mates1 ] => { /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_2_GTCCGC_L005_R1_001_val_1.fq.gz }
# ### [ mates2 ] => { /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_2_GTCCGC_L005_R2_001_val_2.fq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/Nmu_210_HSRNA_2_GTCCGC_L005_R1_001_val_1 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/Nmu_210_HSRNA_2_GTCCGC_L005_R1_001_val_1/logs
# [2020-03-04 14:07:49.133] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 14:07:49.133] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 14:07:49.133] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 14:07:49.133] [jointLog] [info] parsing read library format
# [2020-03-04 14:07:49.133] [jointLog] [info] There is 1 library.
# [2020-03-04 14:07:49.297] [jointLog] [info] Loading pufferfish index
# [2020-03-04 14:07:49.297] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 90.161 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.2446 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 161 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 35.248 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 156.07 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 8.7488 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 73.644 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 10.169 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 310.72 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 14:07:49.686] [jointLog] [info] done
# [2020-03-04 14:07:49.686] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 14:07:49.705] [jointLog] [info] Number of decoys : 0
# [2020-03-04 14:07:50.652] [jointLog] [info] Automatically detected most likely library type as IU
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,001 fragments
# processed 2,000,001 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,001 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,001 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# hits: 19,535,563, hits per frag:  0.75141
#
#
#
#
#
#
#
#
#
# [2020-03-04 14:10:08.630] [jointLog] [info] Computed 88,913 rich equivalence classes for further processing
# [2020-03-04 14:10:08.630] [jointLog] [info] Counted 11,814,395 total reads in the equivalence classes
# [2020-03-04 14:10:08.635] [jointLog] [warning] 0.0146584% of fragments were shorter than the k used to build the index.
# If this fraction is too large, consider re-building the index with a smaller k.
# The minimum read size found was 20.
#
#
# [2020-03-04 14:10:08.635] [jointLog] [info] Number of mappings discarded because of alignment score : 22,152,368
# [2020-03-04 14:10:08.635] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 1,681,994
# [2020-03-04 14:10:08.635] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2020-03-04 14:10:08.635] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 48,781
# [2020-03-04 14:10:08.635] [jointLog] [info] Mapping rate = 45.0052%
#
# [2020-03-04 14:10:08.635] [jointLog] [info] finished quantifyLibrary()
# [2020-03-04 14:10:08.635] [jointLog] [info] Starting optimizer
# [2020-03-04 14:10:08.662] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2020-03-04 14:10:08.665] [jointLog] [info] iteration = 0 | max rel diff. = 23697
# [2020-03-04 14:10:08.906] [jointLog] [info] iteration = 100 | max rel diff. = 4.86498
# [2020-03-04 14:10:09.339] [jointLog] [info] iteration = 200 | max rel diff. = 0.316766
# [2020-03-04 14:10:09.743] [jointLog] [info] iteration = 300 | max rel diff. = 0.0515661
# [2020-03-04 14:10:10.221] [jointLog] [info] iteration = 400 | max rel diff. = 0.578682
# [2020-03-04 14:10:10.341] [jointLog] [info] iteration = 424 | max rel diff. = 0.00542465
# [2020-03-04 14:10:10.342] [jointLog] [info] Finished optimizer
# [2020-03-04 14:10:10.342] [jointLog] [info] writing output
#
# /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_3_GTGAAA_L005_R1_001_val_1.fq.gz
# /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_3_GTGAAA_L005_R2_001_val_2.fq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ mates1 ] => { /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_3_GTGAAA_L005_R1_001_val_1.fq.gz }
# ### [ mates2 ] => { /home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_3_GTGAAA_L005_R2_001_val_2.fq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/Nmu_210_HSRNA_3_GTGAAA_L005_R1_001_val_1 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/Nmu_210_HSRNA_3_GTGAAA_L005_R1_001_val_1/logs
# [2020-03-04 14:10:11.120] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 14:10:11.120] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 14:10:11.120] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 14:10:11.120] [jointLog] [info] parsing read library format
# [2020-03-04 14:10:11.120] [jointLog] [info] There is 1 library.
# [2020-03-04 14:10:11.241] [jointLog] [info] Loading pufferfish index
# [2020-03-04 14:10:11.241] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 119.37 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.0539 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 159.1 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 14.577 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 111.32 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 8.3317 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 86.259 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 9.7061 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 302.77 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 14:10:11.593] [jointLog] [info] done
# [2020-03-04 14:10:11.593] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 14:10:11.609] [jointLog] [info] Number of decoys : 0
# [2020-03-04 14:10:12.753] [jointLog] [info] Automatically detected most likely library type as IU
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,001 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,001 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,001 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# hits: 13,017,166, hits per frag:  0.510722
#
#
#
#
#
#
#
#
#
# [2020-03-04 14:12:29.256] [jointLog] [info] Computed 82,840 rich equivalence classes for further processing
# [2020-03-04 14:12:29.256] [jointLog] [info] Counted 7,916,760 total reads in the equivalence classes
# [2020-03-04 14:12:29.260] [jointLog] [warning] 0.032892% of fragments were shorter than the k used to build the index.
# If this fraction is too large, consider re-building the index with a smaller k.
# The minimum read size found was 20.
#
#
# [2020-03-04 14:12:29.260] [jointLog] [info] Number of mappings discarded because of alignment score : 14,331,707
# [2020-03-04 14:12:29.260] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 1,104,193
# [2020-03-04 14:12:29.260] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2020-03-04 14:12:29.260] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 31,382
# [2020-03-04 14:12:29.260] [jointLog] [info] Mapping rate = 30.6027%
#
# [2020-03-04 14:12:29.260] [jointLog] [info] finished quantifyLibrary()
# [2020-03-04 14:12:29.260] [jointLog] [info] Starting optimizer
# [2020-03-04 14:12:29.280] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2020-03-04 14:12:29.283] [jointLog] [info] iteration = 0 | max rel diff. = 17538.5
# [2020-03-04 14:12:29.622] [jointLog] [info] iteration = 100 | max rel diff. = 16.0345
# [2020-03-04 14:12:30.073] [jointLog] [info] iteration = 200 | max rel diff. = 1.22549
# [2020-03-04 14:12:30.434] [jointLog] [info] iteration = 300 | max rel diff. = 0.226858
# [2020-03-04 14:12:31.045] [jointLog] [info] iteration = 400 | max rel diff. = 2.50452
# [2020-03-04 14:12:31.114] [jointLog] [info] iteration = 431 | max rel diff. = 0.00729515
# [2020-03-04 14:12:31.115] [jointLog] [info] Finished optimizer
# [2020-03-04 14:12:31.115] [jointLog] [info] writing output

# %%
#for paired end reads
for n in range(0, len(fastq_fn_list), 2):
    if "_" in os.path.basename(fastq_fn_list[n]):
    #do germinatedspores
        if os.path.basename(fastq_fn_list[n]).split("_")[1] == 'PGTGS':
            print(fastq_fn_list[n])
            print(fastq_fn_list[n + 1])
            #generate outfolder for each germinatedspores replicate
            QUANT_OUT = os.path.join(OUT_DIR, 'quant', \
                    os.path.basename(fastq_fn_list[n].split('.')[0]))
            if not os.path.exists(QUANT_OUT):
                os.makedirs(QUANT_OUT)
            # !{salmon_exc} quant -i {salmon_index} -l A -1 {fastq_fn_list[n]} -2 {fastq_fn_list[n + 1]} -p 8 --validateMappings -o {QUANT_OUT}
# Out:
# /home/jamila/jamila_Storage/data/expression_data/NMu_PGTGS_1_AGTCAA_L005_R1_001_val_1.fq.gz
# /home/jamila/jamila_Storage/data/expression_data/NMu_PGTGS_1_AGTCAA_L005_R2_001_val_2.fq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ mates1 ] => { /home/jamila/jamila_Storage/data/expression_data/NMu_PGTGS_1_AGTCAA_L005_R1_001_val_1.fq.gz }
# ### [ mates2 ] => { /home/jamila/jamila_Storage/data/expression_data/NMu_PGTGS_1_AGTCAA_L005_R2_001_val_2.fq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/NMu_PGTGS_1_AGTCAA_L005_R1_001_val_1 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/NMu_PGTGS_1_AGTCAA_L005_R1_001_val_1/logs
# [2020-03-04 14:12:32.053] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 14:12:32.053] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 14:12:32.053] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 14:12:32.053] [jointLog] [info] parsing read library format
# [2020-03-04 14:12:32.053] [jointLog] [info] There is 1 library.
# [2020-03-04 14:12:32.134] [jointLog] [info] Loading pufferfish index
# [2020-03-04 14:12:32.134] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 34.175 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.0423 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 145.36 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 15.879 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 105.7 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 7.8814 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 80.581 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 8.7123 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 289.66 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 14:12:32.389] [jointLog] [info] done
# [2020-03-04 14:12:32.389] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 14:12:32.406] [jointLog] [info] Number of decoys : 0
# [2020-03-04 14:12:32.777] [jointLog] [info] Automatically detected most likely library type as IU
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,001 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,001 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,001 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,001 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,001 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,000 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,000 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# hits: 50,667,166, hits per frag:  1.40826
#
#
#
#
#
#
#
#
#
# [2020-03-04 14:15:31.657] [jointLog] [info] Computed 123,040 rich equivalence classes for further processing
# [2020-03-04 14:15:31.657] [jointLog] [info] Counted 28,406,643 total reads in the equivalence classes
# [2020-03-04 14:15:31.663] [jointLog] [warning] 0.014172% of fragments were shorter than the k used to build the index.
# If this fraction is too large, consider re-building the index with a smaller k.
# The minimum read size found was 20.
#
#
# [2020-03-04 14:15:31.663] [jointLog] [info] Number of mappings discarded because of alignment score : 6,967,417
# [2020-03-04 14:15:31.663] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 2,992,846
# [2020-03-04 14:15:31.663] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2020-03-04 14:15:31.663] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 169,103
# [2020-03-04 14:15:31.663] [jointLog] [info] Mapping rate = 78.0646%
#
# [2020-03-04 14:15:31.663] [jointLog] [info] finished quantifyLibrary()
# [2020-03-04 14:15:31.663] [jointLog] [info] Starting optimizer
# [2020-03-04 14:15:32.593] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2020-03-04 14:15:32.598] [jointLog] [info] iteration = 0 | max rel diff. = 31461.6
# [2020-03-04 14:15:32.996] [jointLog] [info] iteration = 100 | max rel diff. = 0.803604
# [2020-03-04 14:15:33.501] [jointLog] [info] iteration = 200 | max rel diff. = 0.0854377
# [2020-03-04 14:15:34.253] [jointLog] [info] iteration = 300 | max rel diff. = 0.0877153
# [2020-03-04 14:15:35.133] [jointLog] [info] iteration = 400 | max rel diff. = 0.195785
# [2020-03-04 14:15:36.002] [jointLog] [info] iteration = 462 | max rel diff. = 0.000987957
# [2020-03-04 14:15:36.006] [jointLog] [info] Finished optimizer
# [2020-03-04 14:15:36.006] [jointLog] [info] writing output
#
# /home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_2_AGTTCC_L005_R1_001_val_1.fq.gz
# /home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_2_AGTTCC_L005_R2_001_val_2.fq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ mates1 ] => { /home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_2_AGTTCC_L005_R1_001_val_1.fq.gz }
# ### [ mates2 ] => { /home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_2_AGTTCC_L005_R2_001_val_2.fq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/Nmu_PGTGS_2_AGTTCC_L005_R1_001_val_1 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/Nmu_PGTGS_2_AGTTCC_L005_R1_001_val_1/logs
# [2020-03-04 14:15:37.558] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 14:15:37.558] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 14:15:37.558] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 14:15:37.558] [jointLog] [info] parsing read library format
# [2020-03-04 14:15:37.558] [jointLog] [info] There is 1 library.
# [2020-03-04 14:15:37.640] [jointLog] [info] Loading pufferfish index
# [2020-03-04 14:15:37.640] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 32.265 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.0871 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 159.5 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 15.915 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 112.22 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 9.4121 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 77.634 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 10.67 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 319.33 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 14:15:37.900] [jointLog] [info] done
# [2020-03-04 14:15:37.900] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 14:15:37.918] [jointLog] [info] Number of decoys : 0
# [2020-03-04 14:15:38.372] [jointLog] [info] Automatically detected most likely library type as IU
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,002 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,001 fragments
# processed 21,000,001 fragments
# processed 21,500,001 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,001 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,000 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# processed 37,000,000 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# processed 38,500,000 fragments
# hits: 57,437,347, hits per frag:  1.49225
#
#
#
#
#
#
#
#
#
# [2020-03-04 14:18:43.516] [jointLog] [info] Computed 127,951 rich equivalence classes for further processing
# [2020-03-04 14:18:43.516] [jointLog] [info] Counted 31,981,816 total reads in the equivalence classes
# [2020-03-04 14:18:43.520] [jointLog] [warning] 0.0157351% of fragments were shorter than the k used to build the index.
# If this fraction is too large, consider re-building the index with a smaller k.
# The minimum read size found was 20.
#
#
# [2020-03-04 14:18:43.520] [jointLog] [info] Number of mappings discarded because of alignment score : 8,868,993
# [2020-03-04 14:18:43.520] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 3,375,252
# [2020-03-04 14:18:43.520] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2020-03-04 14:18:43.520] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 209,218
# [2020-03-04 14:18:43.520] [jointLog] [info] Mapping rate = 82.7418%
#
# [2020-03-04 14:18:43.520] [jointLog] [info] finished quantifyLibrary()
# [2020-03-04 14:18:43.521] [jointLog] [info] Starting optimizer
# [2020-03-04 14:18:43.544] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2020-03-04 14:18:43.548] [jointLog] [info] iteration = 0 | max rel diff. = 30163.2
# [2020-03-04 14:18:44.894] [jointLog] [info] iteration = 100 | max rel diff. = 0.126172
# [2020-03-04 14:18:45.866] [jointLog] [info] iteration = 200 | max rel diff. = 0.0493631
# [2020-03-04 14:18:46.563] [jointLog] [info] iteration = 300 | max rel diff. = 0.0325869
# [2020-03-04 14:18:47.642] [jointLog] [info] iteration = 400 | max rel diff. = 0.066114
# [2020-03-04 14:18:48.260] [jointLog] [info] iteration = 500 | max rel diff. = 0.0407851
# [2020-03-04 14:18:48.715] [jointLog] [info] iteration = 573 | max rel diff. = 0.00632899
# [2020-03-04 14:18:48.720] [jointLog] [info] Finished optimizer
# [2020-03-04 14:18:48.720] [jointLog] [info] writing output
#
# /home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_3_ATGTCA_L005_R1_001_val_1.fq.gz
# /home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_3_ATGTCA_L005_R2_001_val_2.fq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ mates1 ] => { /home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_3_ATGTCA_L005_R1_001_val_1.fq.gz }
# ### [ mates2 ] => { /home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_3_ATGTCA_L005_R2_001_val_2.fq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/Nmu_PGTGS_3_ATGTCA_L005_R1_001_val_1 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/Nmu_PGTGS_3_ATGTCA_L005_R1_001_val_1/logs
# [2020-03-04 14:18:50.029] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 14:18:50.029] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 14:18:50.029] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 14:18:50.029] [jointLog] [info] parsing read library format
# [2020-03-04 14:18:50.029] [jointLog] [info] There is 1 library.
# [2020-03-04 14:18:50.208] [jointLog] [info] Loading pufferfish index
# [2020-03-04 14:18:50.208] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 52.162 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.0264 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 143.48 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 15.894 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 240.61 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 8.4814 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 149.88 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 57.812 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 310.9 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 14:18:50.735] [jointLog] [info] done
# [2020-03-04 14:18:50.735] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 14:18:50.796] [jointLog] [info] Number of decoys : 0
# [2020-03-04 14:18:51.273] [jointLog] [info] Automatically detected most likely library type as IU
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,002 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,001 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,001 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,001 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,001 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,001 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,001 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# processed 37,000,000 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# hits: 56,900,720, hits per frag:  1.49783
#
#
#
#
#
#
#
#
#
# [2020-03-04 14:21:39.577] [jointLog] [info] Computed 120,380 rich equivalence classes for further processing
# [2020-03-04 14:21:39.577] [jointLog] [info] Counted 31,632,701 total reads in the equivalence classes
# [2020-03-04 14:21:39.582] [jointLog] [warning] 0.0178325% of fragments were shorter than the k used to build the index.
# If this fraction is too large, consider re-building the index with a smaller k.
# The minimum read size found was 20.
#
#
# [2020-03-04 14:21:39.582] [jointLog] [info] Number of mappings discarded because of alignment score : 9,598,565
# [2020-03-04 14:21:39.582] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 3,543,525
# [2020-03-04 14:21:39.582] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2020-03-04 14:21:39.582] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 265,342
# [2020-03-04 14:21:39.582] [jointLog] [info] Mapping rate = 83.1378%
#
# [2020-03-04 14:21:39.582] [jointLog] [info] finished quantifyLibrary()
# [2020-03-04 14:21:39.582] [jointLog] [info] Starting optimizer
# [2020-03-04 14:21:39.658] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2020-03-04 14:21:39.680] [jointLog] [info] iteration = 0 | max rel diff. = 30520.9
# [2020-03-04 14:21:40.394] [jointLog] [info] iteration = 100 | max rel diff. = 1.05573
# [2020-03-04 14:21:41.233] [jointLog] [info] iteration = 200 | max rel diff. = 0.269918
# [2020-03-04 14:21:41.740] [jointLog] [info] iteration = 300 | max rel diff. = 0.0705778
# [2020-03-04 14:21:42.196] [jointLog] [info] iteration = 382 | max rel diff. = 0.00590747
# [2020-03-04 14:21:42.201] [jointLog] [info] Finished optimizer
# [2020-03-04 14:21:42.201] [jointLog] [info] writing output

# %%
fastq_fn_list
# Out:
# ['/home/jamila/jamila_Storage/data/expression_data/RW6I3.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW7I1.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW2I1.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW5I3.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW3I1.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW0U3.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_2_GTCCGC_L005_R1_001_val_1.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_1_CCGTCC_L005_R2_001_val_2.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_2_AGTTCC_L005_R2_001_val_2.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW7I2.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW4I1.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW3I2.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_3_ATGTCA_L005_R1_001_val_1.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_3_GTGAAA_L005_R1_001_val_1.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_3_GTGAAA_L005_R2_001_val_2.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW7I3.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_3_ATGTCA_L005_R2_001_val_2.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW0U2.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW4I2.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW2I2.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW6I2.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW5I2.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_2_GTCCGC_L005_R2_001_val_2.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW6I1.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/Nmu_210_HSRNA_1_CCGTCC_L005_R1_001_val_1.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW2I3.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/Nmu_PGTGS_2_AGTTCC_L005_R1_001_val_1.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/NMu_PGTGS_1_AGTCAA_L005_R2_001_val_2.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW0U1.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW4I3.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW3I3.fastq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/NMu_PGTGS_1_AGTCAA_L005_R1_001_val_1.fq.gz',
#  '/home/jamila/jamila_Storage/data/expression_data/RW5I1.fastq.gz']

# %%
#!{salmon_exc} quant -i {salmon-index} -l A \
         #-1 ${fn}/${samp}_1.fastq.gz \
          #${fn}/${samp}_2.fastq.gz \
        # -p 8 --validateMappings -o quants/${samp}_quant

# %% [markdown]
# #now do other reps they might be single end reads
# *the argument -i tells salmon where the index is and the argument -l tells salmon to it should automatically determine the library type of the sequnecing reads.
# *the -1 and -2 tells the salmon where to find the left and right reads for this sample.

# %%
fastq_fn_list = [os.path.join(FASTQ_DIR, x) for x in os.listdir(FASTQ_DIR)]

# %%
for n in range(0, len(fastq_fn_list), 1):
    if "_" not in os.path.basename(fastq_fn_list[n]):
    #do single end
        print(fastq_fn_list[n])
        #print(fastq_fn_list[n + 1])
         #generate outfolder for each germinatedspores replicate
        QUANT_OUT = os.path.join(OUT_DIR, 'quant', \
                os.path.basename(fastq_fn_list[n].split('.')[0]))
        if not os.path.exists(QUANT_OUT):
            os.makedirs(QUANT_OUT)
        # !{salmon_exc} quant -i {salmon_index} -l A -r {fastq_fn_list[n]} -p 8 --validateMappings -o {QUANT_OUT}
# Out:
# /home/jamila/jamila_Storage/data/expression_data/RW0U1.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW0U1.fastq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW0U1 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW0U1/logs
# [2020-03-04 16:53:00.025] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 16:53:00.025] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 16:53:00.025] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 16:53:00.025] [jointLog] [info] parsing read library format
# [2020-03-04 16:53:00.025] [jointLog] [info] There is 1 library.
# [2020-03-04 16:53:00.154] [jointLog] [info] Loading pufferfish index
# [2020-03-04 16:53:00.154] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 50.46 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 998.49 us
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 145.41 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 12.226 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 123.41 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 8.5792 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 69.305 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 10.051 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 297.04 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 16:53:00.430] [jointLog] [info] done
# [2020-03-04 16:53:00.430] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 16:53:00.462] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,001 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,001 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,001 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,002 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,001 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,001 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,001 fragments
# processed 20,500,002 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,001 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,001 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# hits: 10,266; hits per frag:  0.00037375[2020-03-04 16:54:25.267] [jointLog] [error]
#
#
# [2020-03-04 16:54:25.267] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW0U2.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW0U2.fastq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW0U2 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW0U2/logs
# [2020-03-04 16:54:26.458] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 16:54:26.458] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 16:54:26.458] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 16:54:26.458] [jointLog] [info] parsing read library format
# [2020-03-04 16:54:26.458] [jointLog] [info] There is 1 library.
# [2020-03-04 16:54:26.648] [jointLog] [info] Loading pufferfish index
# [2020-03-04 16:54:26.648] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 99.279 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.1685 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 144.94 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 32.773 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 110.88 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 8.5589 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 80.385 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 9.3391 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 299.1 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 16:54:27.009] [jointLog] [info] done
# [2020-03-04 16:54:27.009] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 16:54:27.026] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,001 fragments
# processed 8,000,001 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,001 fragments
# processed 10,000,001 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,001 fragments
# processed 13,000,000 fragments
# processed 13,500,001 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,001 fragments
# processed 15,500,001 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,001 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,001 fragments
# processed 28,000,001 fragments
# hits: 13,494; hits per frag:  0.000482234[2020-03-04 16:55:50.286] [jointLog] [error]
#
#
# [2020-03-04 16:55:50.286] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW0U3.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW0U3.fastq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW0U3 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW0U3/logs
# [2020-03-04 16:55:51.422] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 16:55:51.422] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 16:55:51.422] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 16:55:51.422] [jointLog] [info] parsing read library format
# [2020-03-04 16:55:51.422] [jointLog] [info] There is 1 library.
# -----------------------------------------
# | Loading contig table | Time = 55.16 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 968.59 us
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 146.42 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 16.054 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 144.41 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 8.687 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 78.58 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 8.8652 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 304.65 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 16:55:51.675] [jointLog] [info] Loading pufferfish index
# [2020-03-04 16:55:51.675] [jointLog] [info] Loading dense pufferfish index.
# [2020-03-04 16:55:52.002] [jointLog] [info] done
# [2020-03-04 16:55:52.002] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 16:55:52.019] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,001 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,001 fragments
# processed 3,500,000 fragments
# processed 4,000,002 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,001 fragments
# processed 6,500,000 fragments
# processed 7,000,001 fragments
# processed 7,500,001 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,001 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,001 fragments
# processed 22,500,000 fragments
# processed 23,000,001 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,001 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,001 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# hits: 14,549; hits per frag:  0.000529194[2020-03-04 16:57:14.305] [jointLog] [error]
#
#
# [2020-03-04 16:57:14.305] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW2I1.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW2I1.fastq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW2I1 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW2I1/logs
# [2020-03-04 16:57:14.822] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 16:57:14.822] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 16:57:14.822] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 16:57:14.822] [jointLog] [info] parsing read library format
# [2020-03-04 16:57:14.822] [jointLog] [info] There is 1 library.
# [2020-03-04 16:57:15.009] [jointLog] [info] Loading pufferfish index
# [2020-03-04 16:57:15.009] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 31.831 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.0596 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 145.51 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 15.563 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 102.72 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 9.6599 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 116.13 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 9.5748 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 297.43 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 16:57:15.297] [jointLog] [info] done
# [2020-03-04 16:57:15.297] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 16:57:15.312] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,002 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,001 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,001 fragments
# processed 10,000,001 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,001 fragments
# processed 12,000,000 fragments
# processed 12,500,002 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,001 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,002 fragments
# processed 20,500,000 fragments
# processed 21,000,001 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,001 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,001 fragments
# processed 28,000,000 fragments
# processed 28,500,001 fragments
# processed 29,000,001 fragments
# processed 29,500,001 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,001 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,001 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,001 fragments
# processed 35,500,001 fragments
# processed 36,000,001 fragments
# processed 36,500,000 fragments
# processed 37,000,003 fragments
# processed 37,500,000 fragments
# processed 38,000,001 fragments
# processed 38,500,000 fragments
# processed 39,000,001 fragments
# processed 39,500,001 fragments
# processed 40,000,002 fragments
# processed 40,500,001 fragments
# processed 41,000,000 fragments
# processed 41,500,000 fragments
# processed 42,000,001 fragments
# processed 42,500,001 fragments
# processed 43,000,000 fragments
# processed 43,500,000 fragments
# processed 44,000,000 fragments
# processed 44,500,001 fragments
# processed 45,000,000 fragments
# processed 45,500,000 fragments
# processed 46,000,000 fragments
# hits: 49,737; hits per frag:  0.00108142[2020-03-04 16:59:32.332] [jointLog] [info] Automatically detected most likely library type as U
# processed 46,500,000 fragments
# processed 47,000,000 fragments
# processed 47,500,000 fragments
# processed 48,000,000 fragments
# processed 48,500,000 fragments
# processed 49,000,000 fragments
# processed 49,500,000 fragments
# processed 50,000,001 fragments
# processed 50,500,000 fragments
# processed 51,000,001 fragments
# processed 51,500,001 fragments
# processed 52,000,000 fragments
# processed 52,500,000 fragments
# processed 53,000,000 fragments
# processed 53,500,000 fragments
# processed 54,000,000 fragments
# processed 54,500,000 fragments
# processed 55,000,000 fragments
# processed 55,500,001 fragments
# processed 56,000,000 fragments
# processed 56,500,000 fragments
# processed 57,000,000 fragments
# processed 57,500,000 fragments
# processed 58,000,000 fragments
# processed 58,500,000 fragments
# processed 59,000,001 fragments
# processed 59,500,000 fragments
# processed 60,000,000 fragments
# processed 60,500,000 fragments
# processed 61,000,000 fragments
# processed 61,500,000 fragments
# processed 62,000,000 fragments
# processed 62,500,000 fragments
# processed 63,000,000 fragments
# processed 63,500,000 fragments
# processed 64,000,000 fragments
# processed 64,500,000 fragments
# processed 65,000,000 fragments
# processed 65,500,000 fragments
# processed 66,000,000 fragments
# processed 66,500,000 fragments
# processed 67,000,000 fragments
# processed 67,500,001 fragments
# processed 68,000,000 fragments
# processed 68,500,000 fragments
# processed 69,000,001 fragments
# processed 69,500,000 fragments
# processed 70,000,000 fragments
# processed 70,500,000 fragments
# processed 71,000,001 fragments
# processed 71,500,000 fragments
# processed 72,000,000 fragments
# processed 72,500,000 fragments
# processed 73,000,000 fragments
# processed 73,500,001 fragments
# processed 74,000,000 fragments
# processed 74,500,000 fragments
# processed 75,000,001 fragments
# processed 75,500,001 fragments
# processed 76,000,000 fragments
# processed 76,500,001 fragments
# processed 77,000,000 fragments
# processed 77,500,001 fragments
# processed 78,000,001 fragments
# processed 78,500,000 fragments
# processed 79,000,000 fragments
# processed 79,500,000 fragments
# processed 80,000,000 fragments
# processed 80,500,000 fragments
# processed 81,000,001 fragments
# processed 81,500,000 fragments
# processed 82,000,000 fragments
# processed 82,500,000 fragments
# processed 83,000,001 fragments
# processed 83,500,000 fragments
# processed 84,000,000 fragments
# processed 84,500,000 fragments
# processed 85,000,000 fragments
# processed 85,500,001 fragments
# processed 86,000,000 fragments
# processed 86,500,000 fragments
# processed 87,000,000 fragments
# processed 87,500,000 fragments
# processed 88,000,000 fragments
# processed 88,500,000 fragments
# processed 89,000,000 fragments
# processed 89,500,000 fragments
# processed 90,000,001 fragments
# processed 90,500,001 fragments
# processed 91,000,000 fragments
# processed 91,500,000 fragments
# processed 92,000,000 fragments
# processed 92,500,000 fragments
# processed 93,000,000 fragments
# processed 93,500,000 fragments
# processed 94,000,000 fragments
# processed 94,500,000 fragments
# processed 95,000,000 fragments
# processed 95,500,000 fragments
# processed 96,000,000 fragments
# processed 96,500,000 fragments
# processed 97,000,000 fragments
# processed 97,500,000 fragments
# processed 98,000,000 fragments
# processed 98,500,001 fragments
# processed 99,000,000 fragments
# processed 99,500,000 fragments
# processed 100,000,001 fragments
# processed 100,500,000 fragments
# processed 101,000,001 fragments
# processed 101,500,000 fragments
# processed 102,000,000 fragments
# processed 102,500,001 fragments
# processed 103,000,000 fragments
# processed 103,500,000 fragments
# processed 104,000,000 fragments
# processed 104,500,000 fragments
# processed 105,000,001 fragments
# processed 105,500,002 fragments
# processed 106,000,000 fragments
# processed 106,500,000 fragments
# processed 107,000,000 fragments
# processed 107,500,000 fragments
# processed 108,000,000 fragments
# processed 108,500,000 fragments
# processed 109,000,000 fragments
# processed 109,500,000 fragments
# processed 110,000,000 fragments
# processed 110,500,000 fragments
# processed 111,000,000 fragments
# processed 111,500,000 fragments
# processed 112,000,000 fragments
# processed 112,500,000 fragments
# processed 113,000,000 fragments
# processed 113,500,000 fragments
# processed 114,000,000 fragments
# processed 114,500,000 fragments
# processed 115,000,000 fragments
# processed 115,500,001 fragments
# processed 116,000,000 fragments
# processed 116,500,000 fragments
# processed 117,000,001 fragments
# processed 117,500,000 fragments
# processed 118,000,000 fragments
# processed 118,500,000 fragments
# processed 119,000,000 fragments
# processed 119,500,001 fragments
# processed 120,000,000 fragments
# processed 120,500,000 fragments
# processed 121,000,001 fragments
# processed 121,500,000 fragments
# hits: 131,429; hits per frag:  0.00108196[2020-03-04 17:03:12.394] [jointLog] [error]
#
#
# [2020-03-04 17:03:12.394] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW2I2.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW2I2.fastq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW2I2 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW2I2/logs
# [2020-03-04 17:03:13.217] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 17:03:13.218] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 17:03:13.218] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 17:03:13.218] [jointLog] [info] parsing read library format
# [2020-03-04 17:03:13.218] [jointLog] [info] There is 1 library.
# [2020-03-04 17:03:13.378] [jointLog] [info] Loading pufferfish index
# [2020-03-04 17:03:13.379] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 36.265 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.1208 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 162.47 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 15.715 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 114.16 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 10.171 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 74.699 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 9.9611 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 309.67 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 17:03:13.642] [jointLog] [info] done
# [2020-03-04 17:03:13.642] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 17:03:13.659] [jointLog] [info] Number of decoys : 0
# [2020-03-04 17:03:15.323] [jointLog] [error]
#
#
# [2020-03-04 17:03:15.323] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW2I3.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW2I3.fastq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW2I3 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW2I3/logs
# [2020-03-04 17:03:16.590] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 17:03:16.590] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 17:03:16.590] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 17:03:16.590] [jointLog] [info] parsing read library format
# [2020-03-04 17:03:16.590] [jointLog] [info] There is 1 library.
# -----------------------------------------
# | Loading contig table | Time = 38.795 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 990.42 us
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 149.01 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 14.349 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 112.47 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 10.699 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 185.51 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 9.5379 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 351.08 us
# -----------------------------------------
# [2020-03-04 17:03:16.838] [jointLog] [info] Loading pufferfish index
# [2020-03-04 17:03:16.838] [jointLog] [info] Loading dense pufferfish index.
# [2020-03-04 17:03:17.211] [jointLog] [info] done
# [2020-03-04 17:03:17.211] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 17:03:17.229] [jointLog] [info] Number of decoys : 0
#
#
#
#
# processed 500,000 fragments
# processed 1,000,001 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,001 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,001 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,001 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,001 fragments
# processed 15,500,000 fragments
# processed 16,000,001 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,001 fragments
# processed 19,000,000 fragments
# processed 19,500,001 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,001 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,001 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,001 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# hits: 34,231; hits per frag:  0.00116157[2020-03-04 17:04:44.367] [jointLog] [error]
#
#
# [2020-03-04 17:04:44.367] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW3I1.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW3I1.fastq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW3I1 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW3I1/logs
# [2020-03-04 17:04:45.084] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 17:04:45.084] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 17:04:45.084] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 17:04:45.084] [jointLog] [info] parsing read library format
# [2020-03-04 17:04:45.085] [jointLog] [info] There is 1 library.
# [2020-03-04 17:04:45.265] [jointLog] [info] Loading pufferfish index
# [2020-03-04 17:04:45.265] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 68.019 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.051 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 147.54 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 27.035 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 195.17 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 8.5894 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 72 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 8.7006 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 295.82 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 17:04:45.656] [jointLog] [info] done
# [2020-03-04 17:04:45.656] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 17:04:45.674] [jointLog] [info] Number of decoys : 0
# [2020-03-04 17:04:46.868] [jointLog] [error]
#
#
# [2020-03-04 17:04:46.868] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW3I2.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW3I2.fastq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW3I2 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW3I2/logs
# [2020-03-04 17:04:47.948] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 17:04:47.948] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 17:04:47.948] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 17:04:47.948] [jointLog] [info] parsing read library format
# [2020-03-04 17:04:47.948] [jointLog] [info] There is 1 library.
# [2020-03-04 17:04:48.040] [jointLog] [info] Loading pufferfish index
# [2020-03-04 17:04:48.040] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 98.005 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 874.64 us
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 127.88 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 40.309 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 238.13 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 9.2096 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 68.646 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 12.4 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 321.88 us
# -----------------------------------------
# [2020-03-04 17:04:48.522] [jointLog] [info] done
# [2020-03-04 17:04:48.522] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 17:04:48.546] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,001 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,001 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,001 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,001 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,001 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,001 fragments
# processed 19,000,000 fragments
# processed 19,500,001 fragments
# processed 20,000,002 fragments
# processed 20,500,000 fragments
# processed 21,000,001 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,001 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# hits: 49,502; hits per frag:  0.00202158[2020-03-04 17:05:59.260] [jointLog] [info] Automatically detected most likely library type as SR
# processed 25,000,001 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,001 fragments
# processed 31,500,001 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,001 fragments
# processed 35,000,001 fragments
# processed 35,500,001 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# processed 37,000,000 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# processed 38,500,001 fragments
# processed 39,000,000 fragments
# processed 39,500,000 fragments
# processed 40,000,000 fragments
# processed 40,500,000 fragments
# processed 41,000,000 fragments
# processed 41,500,001 fragments
# processed 42,000,000 fragments
# processed 42,500,000 fragments
# processed 43,000,000 fragments
# processed 43,500,000 fragments
# processed 44,000,000 fragments
# processed 44,500,000 fragments
# processed 45,000,001 fragments
# processed 45,500,000 fragments
# processed 46,000,000 fragments
# processed 46,500,000 fragments
# processed 47,000,000 fragments
# processed 47,500,000 fragments
# processed 48,000,000 fragments
# processed 48,500,000 fragments
# processed 49,000,000 fragments
# processed 49,500,001 fragments
# processed 50,000,000 fragments
# processed 50,500,000 fragments
# processed 51,000,000 fragments
# processed 51,500,001 fragments
# processed 52,000,000 fragments
# processed 52,500,001 fragments
# processed 53,000,000 fragments
# processed 53,500,001 fragments
# processed 54,000,001 fragments
# processed 54,500,000 fragments
# processed 55,000,002 fragments
# processed 55,500,000 fragments
# processed 56,000,001 fragments
# processed 56,500,001 fragments
# processed 57,000,000 fragments
# processed 57,500,001 fragments
# processed 58,000,000 fragments
# processed 58,500,000 fragments
# processed 59,000,001 fragments
# processed 59,500,000 fragments
# processed 60,000,000 fragments
# processed 60,500,001 fragments
# processed 61,000,001 fragments
# processed 61,500,001 fragments
# processed 62,000,003 fragments
# processed 62,500,000 fragments
# processed 63,000,000 fragments
# processed 63,500,000 fragments
# processed 64,000,000 fragments
# processed 64,500,000 fragments
# processed 65,000,000 fragments
# processed 65,500,000 fragments
# processed 66,000,000 fragments
# processed 66,500,000 fragments
# processed 67,000,000 fragments
# processed 67,500,000 fragments
# processed 68,000,000 fragments
# processed 68,500,000 fragments
# processed 69,000,000 fragments
# processed 69,500,000 fragments
# processed 70,000,000 fragments
# processed 70,500,000 fragments
# processed 71,000,000 fragments
# processed 71,500,000 fragments
# processed 72,000,000 fragments
# processed 72,500,000 fragments
# processed 73,000,000 fragments
# processed 73,500,001 fragments
# processed 74,000,000 fragments
# processed 74,500,000 fragments
# processed 75,000,000 fragments
# processed 75,500,001 fragments
# processed 76,000,000 fragments
# processed 76,500,001 fragments
# processed 77,000,000 fragments
# processed 77,500,000 fragments
# processed 78,000,000 fragments
# processed 78,500,000 fragments
# processed 79,000,000 fragments
# processed 79,500,000 fragments
# processed 80,000,000 fragments
# processed 80,500,000 fragments
# processed 81,000,000 fragments
# processed 81,500,000 fragments
# processed 82,000,000 fragments
# processed 82,500,000 fragments
# processed 83,000,001 fragments
# processed 83,500,000 fragments
# processed 84,000,000 fragments
# processed 84,500,001 fragments
# processed 85,000,001 fragments
# processed 85,500,000 fragments
# processed 86,000,001 fragments
# processed 86,500,001 fragments
# processed 87,000,000 fragments
# processed 87,500,000 fragments
# processed 88,000,001 fragments
# processed 88,500,000 fragments
# processed 89,000,000 fragments
# processed 89,500,000 fragments
# processed 90,000,000 fragments
# processed 90,500,000 fragments
# processed 91,000,000 fragments
# processed 91,500,000 fragments
# processed 92,000,000 fragments
# processed 92,500,000 fragments
# processed 93,000,000 fragments
# processed 93,500,001 fragments
# processed 94,000,000 fragments
# processed 94,500,000 fragments
# processed 95,000,000 fragments
# processed 95,500,000 fragments
# processed 96,000,000 fragments
# processed 96,500,001 fragments
# processed 97,000,000 fragments
# processed 97,500,001 fragments
# processed 98,000,000 fragments
# processed 98,500,000 fragments
# processed 99,000,000 fragments
# processed 99,500,000 fragments
# processed 100,000,000 fragments
# processed 100,500,001 fragments
# processed 101,000,000 fragments
# processed 101,500,000 fragments
# processed 102,000,000 fragments
# processed 102,500,000 fragments
# processed 103,000,001 fragments
# processed 103,500,000 fragments
# processed 104,000,000 fragments
# processed 104,500,001 fragments
# processed 105,000,000 fragments
# processed 105,500,000 fragments
# processed 106,000,000 fragments
# processed 106,500,000 fragments
# processed 107,000,000 fragments
# processed 107,500,000 fragments
# processed 108,000,000 fragments
# processed 108,500,000 fragments
# processed 109,000,000 fragments
# processed 109,500,001 fragments
# processed 110,000,000 fragments
# processed 110,500,000 fragments
# processed 111,000,000 fragments
# processed 111,500,000 fragments
# processed 112,000,001 fragments
# processed 112,500,000 fragments
# hits: 224,591; hits per frag:  0.00199665[2020-03-04 17:10:09.178] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-04 17:10:09.192] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-04 17:10:09.197] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-04 17:10:09.197] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-04 17:10:09.207] [jointLog] [info] Thread saw mini-batch with a maximum of 0.18% zero probability fragments
# [2020-03-04 17:10:09.218] [jointLog] [info] Thread saw mini-batch with a maximum of 0.20% zero probability fragments
# [2020-03-04 17:10:09.220] [jointLog] [info] Thread saw mini-batch with a maximum of 0.18% zero probability fragments
# [2020-03-04 17:10:09.253] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-04 17:10:09.255] [jointLog] [error]
#
#
# ...
# [2020-03-04 17:35:47.155] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 32.906 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.0937 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 150.39 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 15.895 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 100.65 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 10.254 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 79.417 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 10.892 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 336.65 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 17:35:47.407] [jointLog] [info] done
# [2020-03-04 17:35:47.407] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 17:35:47.425] [jointLog] [info] Number of decoys : 0
# [2020-03-04 17:35:48.921] [jointLog] [info] Automatically detected most likely library type as SR
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,001 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,001 fragments
# processed 9,000,000 fragments
# processed 9,500,002 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,001 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,001 fragments
# processed 18,500,002 fragments
# processed 19,000,000 fragments
# processed 19,500,001 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,001 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# hits: 5,452,687; hits per frag:  0.218201[2020-03-04 17:37:00.921] [jointLog] [info] Thread saw mini-batch with a maximum of 0.38% zero probability fragments
# [2020-03-04 17:37:00.934] [jointLog] [info] Thread saw mini-batch with a maximum of 0.38% zero probability fragments
# [2020-03-04 17:37:00.936] [jointLog] [info] Thread saw mini-batch with a maximum of 0.36% zero probability fragments
# [2020-03-04 17:37:00.943] [jointLog] [info] Thread saw mini-batch with a maximum of 0.32% zero probability fragments
# [2020-03-04 17:37:00.956] [jointLog] [info] Thread saw mini-batch with a maximum of 0.34% zero probability fragments
# [2020-03-04 17:37:00.959] [jointLog] [info] Thread saw mini-batch with a maximum of 0.42% zero probability fragments
# [2020-03-04 17:37:00.975] [jointLog] [info] Thread saw mini-batch with a maximum of 0.46% zero probability fragments
# [2020-03-04 17:37:00.998] [jointLog] [info] Thread saw mini-batch with a maximum of 0.38% zero probability fragments
# [2020-03-04 17:37:00.999] [jointLog] [error]
#
#
# [2020-03-04 17:37:00.999] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW7I2.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW7I2.fastq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW7I2 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW7I2/logs
# [2020-03-04 17:37:01.951] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 17:37:01.951] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 17:37:01.993] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 17:37:01.993] [jointLog] [info] parsing read library format
# [2020-03-04 17:37:01.993] [jointLog] [info] There is 1 library.
# [2020-03-04 17:37:02.140] [jointLog] [info] Loading pufferfish index
# [2020-03-04 17:37:02.140] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 68.373 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.1739 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 156.15 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 36.596 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 125.15 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 8.9117 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 79.001 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 9.064 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 308.38 us
# -----------------------------------------
#
#
#
#
# [2020-03-04 17:37:02.476] [jointLog] [info] done
# [2020-03-04 17:37:02.476] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 17:37:02.493] [jointLog] [info] Number of decoys : 0
# [2020-03-04 17:37:03.721] [jointLog] [info] Automatically detected most likely library type as SR
# processed 500,000 fragments
# processed 1,000,001 fragments
# processed 1,500,001 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,001 fragments
# processed 3,500,000 fragments
# processed 4,000,001 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,001 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,001 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,001 fragments
# processed 9,500,000 fragments
# processed 10,000,001 fragments
# processed 10,500,001 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,001 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,001 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,001 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,001 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,001 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,001 fragments
# hits: 4,611,114; hits per frag:  0.192409[2020-03-04 17:38:12.564] [jointLog] [info] Thread saw mini-batch with a maximum of 0.34% zero probability fragments
# [2020-03-04 17:38:12.577] [jointLog] [info] Thread saw mini-batch with a maximum of 0.36% zero probability fragments
# [2020-03-04 17:38:12.598] [jointLog] [info] Thread saw mini-batch with a maximum of 0.36% zero probability fragments
# [2020-03-04 17:38:12.602] [jointLog] [info] Thread saw mini-batch with a maximum of 0.32% zero probability fragments
# [2020-03-04 17:38:12.610] [jointLog] [info] Thread saw mini-batch with a maximum of 0.38% zero probability fragments
# [2020-03-04 17:38:12.621] [jointLog] [info] Thread saw mini-batch with a maximum of 0.34% zero probability fragments
# [2020-03-04 17:38:12.640] [jointLog] [info] Thread saw mini-batch with a maximum of 0.38% zero probability fragments
# [2020-03-04 17:38:12.646] [jointLog] [info] Thread saw mini-batch with a maximum of 0.30% zero probability fragments
# [2020-03-04 17:38:12.647] [jointLog] [error]
#
#
# [2020-03-04 17:38:12.647] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW7I3.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { A }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW7I3.fastq.gz }
# ### [ threads ] => { 8 }
# ### [ validateMappings ] => { }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW7I3 }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW7I3/logs
# [2020-03-04 17:38:13.803] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-04 17:38:13.803] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-04 17:38:13.803] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-04 17:38:13.803] [jointLog] [info] parsing read library format
# [2020-03-04 17:38:13.803] [jointLog] [info] There is 1 library.
# -----------------------------------------
# | Loading contig table | Time = 65.34 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 3.2611 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 166.83 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 57.094 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 172.71 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 14.386 ms
# -----------------------------------------
# size = 33281546
# [2020-03-04 17:38:14.049] [jointLog] [info] Loading pufferfish index
# [2020-03-04 17:38:14.049] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading positions | Time = 145.36 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 7.6062 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 260.1 us
# -----------------------------------------
# [2020-03-04 17:38:14.534] [jointLog] [info] done
# [2020-03-04 17:38:14.534] [jointLog] [info] Index contained 37,708 targets
# [2020-03-04 17:38:14.549] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2020-03-04 17:38:15.877] [jointLog] [info] Automatically detected most likely library type as SR
# processed 500,001 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,001 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,001 fragments
# processed 4,500,001 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,001 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,001 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,001 fragments
# processed 13,000,001 fragments
# processed 13,500,001 fragments
# processed 14,000,001 fragments
# processed 14,500,000 fragments
# processed 15,000,001 fragments
# processed 15,500,001 fragments
# processed 16,000,001 fragments
# processed 16,500,002 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,001 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,001 fragments
# processed 26,000,000 fragments
# hits: 6,839,781; hits per frag:  0.263216[2020-03-04 17:39:36.302] [jointLog] [info] Thread saw mini-batch with a maximum of 0.34% zero probability fragments
# [2020-03-04 17:39:36.315] [jointLog] [info] Thread saw mini-batch with a maximum of 0.40% zero probability fragments
# [2020-03-04 17:39:36.315] [jointLog] [info] Thread saw mini-batch with a maximum of 0.36% zero probability fragments
# [2020-03-04 17:39:36.358] [jointLog] [info] Thread saw mini-batch with a maximum of 0.32% zero probability fragments
# [2020-03-04 17:39:36.360] [jointLog] [info] Thread saw mini-batch with a maximum of 0.32% zero probability fragments
# [2020-03-04 17:39:36.360] [jointLog] [info] Thread saw mini-batch with a maximum of 0.32% zero probability fragments
# [2020-03-04 17:39:36.379] [jointLog] [info] Thread saw mini-batch with a maximum of 0.32% zero probability fragments
# [2020-03-04 17:39:36.379] [jointLog] [info] Thread saw mini-batch with a maximum of 0.32% zero probability fragments
# [2020-03-04 17:39:36.380] [jointLog] [error]
#
#
# [2020-03-04 17:39:36.380] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.

# %%
(fastq_fn_list[n])
# Out:
# '/home/jamila/jamila_Storage/data/expression_data/RW5I1.fastq.gz'

# %%
for n in range(0, len(fastq_fn_list), 1):
    if "_" not in os.path.basename(fastq_fn_list[n]):
    #do single end
        print(fastq_fn_list[n])
        #print(fastq_fn_list[n + 1])
         #generate outfolder for each germinatedspores replicate
        QUANT_OUT = os.path.join(OUT_DIR, 'quant', \
                os.path.basename(fastq_fn_list[n].split('.')[0]))
        if not os.path.exists(QUANT_OUT):
            os.makedirs(QUANT_OUT)
        # !{salmon_exc} quant --validateMappings -i {salmon_index} --libType SR -r {fastq_fn_list[n]} -p 4 -o {QUANT_OUT} --writeMappings={QUANT_OUT}
# Out:
# /home/jamila/jamila_Storage/data/expression_data/RW6I3.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ validateMappings ] => { }
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { SR }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW6I3.fastq.gz }
# ### [ threads ] => { 4 }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW6I3 }
# ### [ writeMappings ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW6I3/mapping.sam }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW6I3/logs
# [2020-03-05 15:56:15.451] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-05 15:56:15.451] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-05 15:56:15.451] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-05 15:56:15.451] [jointLog] [info] parsing read library format
# [2020-03-05 15:56:15.451] [jointLog] [info] There is 1 library.
# [2020-03-05 15:56:15.560] [jointLog] [info] Loading pufferfish index
# [2020-03-05 15:56:15.560] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 37.188 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.3252 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 178.92 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 18.575 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 106.62 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 11.991 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 108.93 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 10.97 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 362.92 us
# -----------------------------------------
#
#
#
#
# [2020-03-05 15:56:15.857] [jointLog] [info] done
# [2020-03-05 15:56:15.857] [jointLog] [info] Index contained 37,708 targets
# [2020-03-05 15:56:15.876] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,001 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,001 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,001 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,001 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,001 fragments
# hits: 2,312,539; hits per frag:  0.0925238[2020-03-05 15:58:52.542] [jointLog] [info] Thread saw mini-batch with a maximum of 0.22% zero probability fragments
# [2020-03-05 15:58:52.585] [jointLog] [info] Thread saw mini-batch with a maximum of 0.22% zero probability fragments
# [2020-03-05 15:58:52.616] [jointLog] [info] Thread saw mini-batch with a maximum of 0.22% zero probability fragments
# [2020-03-05 15:58:52.666] [jointLog] [info] Thread saw mini-batch with a maximum of 0.24% zero probability fragments
# [2020-03-05 15:58:52.667] [jointLog] [error]
#
#
# [2020-03-05 15:58:52.667] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW7I1.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ validateMappings ] => { }
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { SR }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW7I1.fastq.gz }
# ### [ threads ] => { 4 }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW7I1 }
# ### [ writeMappings ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW7I1/mapping.sam }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW7I1/logs
# [2020-03-05 15:58:54.087] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-05 15:58:54.087] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-05 15:58:54.087] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-05 15:58:54.087] [jointLog] [info] parsing read library format
# [2020-03-05 15:58:54.087] [jointLog] [info] There is 1 library.
# [2020-03-05 15:58:54.168] [jointLog] [info] Loading pufferfish index
# [2020-03-05 15:58:54.168] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 34.329 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.2883 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 155.4 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 16.394 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 102.37 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 9.6326 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 88.873 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 10.32 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 334.62 us
# -----------------------------------------
#
#
#
#
# [2020-03-05 15:58:54.433] [jointLog] [info] done
# [2020-03-05 15:58:54.433] [jointLog] [info] Index contained 37,708 targets
# [2020-03-05 15:58:54.448] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,001 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,001 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,001 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# hits: 5,451,372; hits per frag:  0.218165[2020-03-05 16:01:22.417] [jointLog] [info] Thread saw mini-batch with a maximum of 0.46% zero probability fragments
# [2020-03-05 16:01:22.439] [jointLog] [info] Thread saw mini-batch with a maximum of 0.36% zero probability fragments
# [2020-03-05 16:01:22.484] [jointLog] [info] Thread saw mini-batch with a maximum of 0.38% zero probability fragments
# [2020-03-05 16:01:22.498] [jointLog] [info] Thread saw mini-batch with a maximum of 0.34% zero probability fragments
# [2020-03-05 16:01:22.498] [jointLog] [error]
#
#
# [2020-03-05 16:01:22.499] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW2I1.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ validateMappings ] => { }
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { SR }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW2I1.fastq.gz }
# ### [ threads ] => { 4 }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW2I1 }
# ### [ writeMappings ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW2I1/mapping.sam }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW2I1/logs
# [2020-03-05 16:01:23.215] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-05 16:01:23.215] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-05 16:01:23.215] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-05 16:01:23.215] [jointLog] [info] parsing read library format
# [2020-03-05 16:01:23.215] [jointLog] [info] There is 1 library.
# [2020-03-05 16:01:23.296] [jointLog] [info] Loading pufferfish index
# [2020-03-05 16:01:23.296] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 32.085 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.1334 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 173.05 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 15.81 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 95.204 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 9.4614 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 86.381 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 9.8889 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 318.41 us
# -----------------------------------------
#
#
#
#
# [2020-03-05 16:01:23.547] [jointLog] [info] done
# [2020-03-05 16:01:23.547] [jointLog] [info] Index contained 37,708 targets
# [2020-03-05 16:01:23.562] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,001 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,001 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,001 fragments
# processed 7,500,001 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,001 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,001 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,001 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,001 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,000 fragments
# processed 31,500,001 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,000 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# processed 37,000,001 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# processed 38,500,000 fragments
# processed 39,000,000 fragments
# processed 39,500,000 fragments
# processed 40,000,000 fragments
# processed 40,500,000 fragments
# processed 41,000,000 fragments
# processed 41,500,000 fragments
# processed 42,000,000 fragments
# processed 42,500,000 fragments
# processed 43,000,000 fragments
# processed 43,500,000 fragments
# processed 44,000,000 fragments
# processed 44,500,000 fragments
# processed 45,000,000 fragments
# processed 45,500,000 fragments
# processed 46,000,000 fragments
# processed 46,500,000 fragments
# processed 47,000,000 fragments
# processed 47,500,000 fragments
# processed 48,000,000 fragments
# processed 48,500,000 fragments
# processed 49,000,000 fragments
# processed 49,500,000 fragments
# processed 50,000,000 fragments
# processed 50,500,000 fragments
# processed 51,000,001 fragments
# processed 51,500,001 fragments
# processed 52,000,000 fragments
# processed 52,500,000 fragments
# processed 53,000,000 fragments
# processed 53,500,000 fragments
# processed 54,000,001 fragments
# processed 54,500,000 fragments
# processed 55,000,000 fragments
# processed 55,500,000 fragments
# processed 56,000,000 fragments
# processed 56,500,000 fragments
# processed 57,000,000 fragments
# processed 57,500,000 fragments
# processed 58,000,000 fragments
# processed 58,500,000 fragments
# processed 59,000,000 fragments
# processed 59,500,000 fragments
# processed 60,000,000 fragments
# processed 60,500,000 fragments
# processed 61,000,000 fragments
# processed 61,500,000 fragments
# processed 62,000,000 fragments
# processed 62,500,000 fragments
# processed 63,000,000 fragments
# processed 63,500,000 fragments
# processed 64,000,000 fragments
# processed 64,500,000 fragments
# processed 65,000,000 fragments
# processed 65,500,000 fragments
# processed 66,000,000 fragments
# processed 66,500,000 fragments
# processed 67,000,000 fragments
# processed 67,500,001 fragments
# processed 68,000,000 fragments
# processed 68,500,000 fragments
# processed 69,000,000 fragments
# processed 69,500,000 fragments
# processed 70,000,000 fragments
# processed 70,500,000 fragments
# processed 71,000,000 fragments
# processed 71,500,001 fragments
# processed 72,000,000 fragments
# processed 72,500,000 fragments
# processed 73,000,000 fragments
# processed 73,500,000 fragments
# processed 74,000,000 fragments
# processed 74,500,000 fragments
# processed 75,000,000 fragments
# processed 75,500,000 fragments
# processed 76,000,000 fragments
# processed 76,500,000 fragments
# processed 77,000,000 fragments
# processed 77,500,000 fragments
# processed 78,000,000 fragments
# processed 78,500,000 fragments
# processed 79,000,000 fragments
# processed 79,500,000 fragments
# processed 80,000,000 fragments
# processed 80,500,000 fragments
# processed 81,000,000 fragments
# processed 81,500,000 fragments
# processed 82,000,001 fragments
# processed 82,500,000 fragments
# processed 83,000,000 fragments
# processed 83,500,000 fragments
# processed 84,000,001 fragments
# processed 84,500,000 fragments
# processed 85,000,001 fragments
# processed 85,500,000 fragments
# processed 86,000,001 fragments
# processed 86,500,001 fragments
# processed 87,000,001 fragments
# processed 87,500,000 fragments
# processed 88,000,000 fragments
# processed 88,500,000 fragments
# processed 89,000,000 fragments
# processed 89,500,001 fragments
# processed 90,000,000 fragments
# processed 90,500,000 fragments
# processed 91,000,000 fragments
# processed 91,500,000 fragments
# processed 92,000,000 fragments
# processed 92,500,000 fragments
# processed 93,000,000 fragments
# processed 93,500,000 fragments
# processed 94,000,001 fragments
# processed 94,500,000 fragments
# processed 95,000,000 fragments
# processed 95,500,000 fragments
# processed 96,000,000 fragments
# processed 96,500,003 fragments
# processed 97,000,000 fragments
# processed 97,500,000 fragments
# processed 98,000,000 fragments
# processed 98,500,000 fragments
# processed 99,000,000 fragments
# processed 99,500,000 fragments
# processed 100,000,000 fragments
# processed 100,500,000 fragments
# processed 101,000,000 fragments
# processed 101,500,000 fragments
# processed 102,000,000 fragments
# processed 102,500,000 fragments
# processed 103,000,001 fragments
# processed 103,500,000 fragments
# processed 104,000,000 fragments
# processed 104,500,001 fragments
# processed 105,000,000 fragments
# processed 105,500,000 fragments
# processed 106,000,000 fragments
# processed 106,500,000 fragments
# processed 107,000,000 fragments
# processed 107,500,000 fragments
# processed 108,000,000 fragments
# processed 108,500,000 fragments
# processed 109,000,000 fragments
# processed 109,500,001 fragments
# processed 110,000,000 fragments
# processed 110,500,000 fragments
# processed 111,000,000 fragments
# processed 111,500,000 fragments
# processed 112,000,001 fragments
# processed 112,500,000 fragments
# processed 113,000,000 fragments
# processed 113,500,000 fragments
# processed 114,000,001 fragments
# processed 114,500,000 fragments
# processed 115,000,001 fragments
# processed 115,500,000 fragments
# processed 116,000,000 fragments
# processed 116,500,000 fragments
# processed 117,000,000 fragments
# processed 117,500,000 fragments
# processed 118,000,000 fragments
# processed 118,500,000 fragments
# processed 119,000,000 fragments
# processed 119,500,000 fragments
# processed 120,000,000 fragments
# processed 120,500,001 fragments
# processed 121,000,000 fragments
# processed 121,500,000 fragments
# hits: 131,426; hits per frag:  0.00108181[2020-03-05 16:12:30.217] [jointLog] [info] Thread saw mini-batch with a maximum of 0.14% zero probability fragments
# [2020-03-05 16:12:30.236] [jointLog] [info] Thread saw mini-batch with a maximum of 0.14% zero probability fragments
# [2020-03-05 16:12:30.274] [jointLog] [info] Thread saw mini-batch with a maximum of 0.14% zero probability fragments
# [2020-03-05 16:12:30.321] [jointLog] [info] Thread saw mini-batch with a maximum of 0.12% zero probability fragments
# [2020-03-05 16:12:30.322] [jointLog] [error]
#
#
# [2020-03-05 16:12:30.322] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW5I3.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ validateMappings ] => { }
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { SR }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW5I3.fastq.gz }
# ### [ threads ] => { 4 }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW5I3 }
# ### [ writeMappings ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW5I3/mapping.sam }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW5I3/logs
# [2020-03-05 16:12:31.257] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-05 16:12:31.257] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-05 16:12:31.257] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-05 16:12:31.257] [jointLog] [info] parsing read library format
# [2020-03-05 16:12:31.257] [jointLog] [info] There is 1 library.
# [2020-03-05 16:12:31.339] [jointLog] [info] Loading pufferfish index
# [2020-03-05 16:12:31.339] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 33.265 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.2707 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 179.76 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 16.186 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 97.007 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 10.619 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 77.11 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 9.8694 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 319.07 us
# -----------------------------------------
#
#
#
#
# [2020-03-05 16:12:31.585] [jointLog] [info] done
# [2020-03-05 16:12:31.585] [jointLog] [info] Index contained 37,708 targets
# [2020-03-05 16:12:31.600] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,001 fragments
# processed 3,500,001 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,001 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,001 fragments
# processed 11,500,000 fragments
# processed 12,000,002 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,001 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,001 fragments
# processed 24,500,000 fragments
# processed 25,000,001 fragments
# processed 25,500,000 fragments
# processed 26,000,001 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,000 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,001 fragments
# processed 35,000,000 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# processed 37,000,000 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# processed 38,500,000 fragments
# processed 39,000,000 fragments
# processed 39,500,000 fragments
# processed 40,000,001 fragments
# processed 40,500,000 fragments
# processed 41,000,001 fragments
# processed 41,500,000 fragments
# processed 42,000,000 fragments
# processed 42,500,000 fragments
# processed 43,000,000 fragments
# processed 43,500,001 fragments
# processed 44,000,000 fragments
# processed 44,500,000 fragments
# processed 45,000,000 fragments
# processed 45,500,000 fragments
# processed 46,000,000 fragments
# processed 46,500,000 fragments
# processed 47,000,000 fragments
# processed 47,500,001 fragments
# processed 48,000,000 fragments
# processed 48,500,000 fragments
# processed 49,000,000 fragments
# processed 49,500,001 fragments
# processed 50,000,000 fragments
# processed 50,500,000 fragments
# processed 51,000,000 fragments
# processed 51,500,001 fragments
# processed 52,000,000 fragments
# processed 52,500,000 fragments
# processed 53,000,000 fragments
# processed 53,500,000 fragments
# processed 54,000,000 fragments
# processed 54,500,000 fragments
# processed 55,000,000 fragments
# processed 55,500,000 fragments
# processed 56,000,000 fragments
# processed 56,500,000 fragments
# processed 57,000,000 fragments
# processed 57,500,000 fragments
# processed 58,000,000 fragments
# processed 58,500,001 fragments
# processed 59,000,000 fragments
# processed 59,500,000 fragments
# processed 60,000,000 fragments
# processed 60,500,000 fragments
# processed 61,000,000 fragments
# processed 61,500,000 fragments
# processed 62,000,000 fragments
# processed 62,500,000 fragments
# processed 63,000,000 fragments
# processed 63,500,001 fragments
# processed 64,000,000 fragments
# processed 64,500,000 fragments
# processed 65,000,000 fragments
# processed 65,500,000 fragments
# processed 66,000,001 fragments
# processed 66,500,001 fragments
# processed 67,000,000 fragments
# processed 67,500,000 fragments
# processed 68,000,001 fragments
# processed 68,500,000 fragments
# processed 69,000,001 fragments
# processed 69,500,000 fragments
# processed 70,000,000 fragments
# processed 70,500,000 fragments
# processed 71,000,000 fragments
# processed 71,500,000 fragments
# processed 72,000,000 fragments
# processed 72,500,001 fragments
# processed 73,000,000 fragments
# processed 73,500,001 fragments
# processed 74,000,001 fragments
# processed 74,500,000 fragments
# processed 75,000,000 fragments
# processed 75,500,001 fragments
# processed 76,000,000 fragments
# processed 76,500,000 fragments
# processed 77,000,001 fragments
# processed 77,500,000 fragments
# processed 78,000,000 fragments
# processed 78,500,000 fragments
# processed 79,000,000 fragments
# processed 79,500,000 fragments
# hits: 2,720,705; hits per frag:  0.0342243[2020-03-05 16:20:11.756] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-05 16:20:11.778] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-05 16:20:11.833] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-05 16:20:11.848] [jointLog] [info] Thread saw mini-batch with a maximum of 0.18% zero probability fragments
#
#
#
#
# [2020-03-05 16:20:11.893] [jointLog] [info] Computed 51,002 rich equivalence classes for further processing
# [2020-03-05 16:20:11.893] [jointLog] [info] Counted 1,347,524 total reads in the equivalence classes
#
#
#
#
#
#
# [2020-03-05 16:20:11.896] [jointLog] [warning] 0.0720314% of fragments were shorter than the k used to build the index.
# If this fraction is too large, consider re-building the index with a smaller k.
# The minimum read size found was 25.
#
#
# [2020-03-05 16:20:11.896] [jointLog] [info] Number of mappings discarded because of alignment score : 1,338,804
# [2020-03-05 16:20:11.896] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 102,725
# [2020-03-05 16:20:11.896] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2020-03-05 16:20:11.896] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 0
# [2020-03-05 16:20:11.899] [jointLog] [warning] Only 1347524 fragments were mapped, but the number of burn-in fragments was set to 5000000.
# The effective lengths have been computed using the observed mappings.
#
# [2020-03-05 16:20:11.899] [jointLog] [info] Mapping rate = 1.69311%
#
# [2020-03-05 16:20:11.899] [jointLog] [info] finished quantifyLibrary()
# [2020-03-05 16:20:11.900] [jointLog] [info] Starting optimizer
# [2020-03-05 16:20:11.919] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2020-03-05 16:20:11.923] [jointLog] [info] iteration = 0 | max rel diff. = 3442.75
# [2020-03-05 16:20:12.204] [jointLog] [info] iteration = 100 | max rel diff. = 4.08366
# [2020-03-05 16:20:12.558] [jointLog] [info] iteration = 200 | max rel diff. = 1.83788
# [2020-03-05 16:20:12.912] [jointLog] [info] iteration = 293 | max rel diff. = 0.00764061
# [2020-03-05 16:20:12.913] [jointLog] [info] Finished optimizer
# [2020-03-05 16:20:12.913] [jointLog] [info] writing output
#
# /home/jamila/jamila_Storage/data/expression_data/RW3I1.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ validateMappings ] => { }
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { SR }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW3I1.fastq.gz }
# ### [ threads ] => { 4 }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW3I1 }
# ### [ writeMappings ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW3I1/mapping.sam }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW3I1/logs
# [2020-03-05 16:20:14.378] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-05 16:20:14.378] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-05 16:20:14.378] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-05 16:20:14.378] [jointLog] [info] parsing read library format
# [2020-03-05 16:20:14.378] [jointLog] [info] There is 1 library.
# [2020-03-05 16:20:14.460] [jointLog] [info] Loading pufferfish index
# [2020-03-05 16:20:14.460] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 33.189 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.181 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 170.35 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 17.43 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 98.267 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 9.8316 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 85.762 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 10.217 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 330.84 us
# -----------------------------------------
#
#
#
#
# [2020-03-05 16:20:14.717] [jointLog] [info] done
# [2020-03-05 16:20:14.717] [jointLog] [info] Index contained 37,708 targets
# [2020-03-05 16:20:14.732] [jointLog] [info] Number of decoys : 0
# [2020-03-05 16:20:17.012] [jointLog] [info] Thread saw mini-batch with a maximum of 0.06% zero probability fragments
# [2020-03-05 16:20:17.103] [jointLog] [info] Thread saw mini-batch with a maximum of 0.08% zero probability fragments
# [2020-03-05 16:20:17.109] [jointLog] [info] Thread saw mini-batch with a maximum of 0.06% zero probability fragments
# [2020-03-05 16:20:17.124] [jointLog] [info] Thread saw mini-batch with a maximum of 0.06% zero probability fragments
# [2020-03-05 16:20:17.124] [jointLog] [error]
#
#
# [2020-03-05 16:20:17.124] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW0U3.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ validateMappings ] => { }
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { SR }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW0U3.fastq.gz }
# ### [ threads ] => { 4 }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW0U3 }
# ### [ writeMappings ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW0U3/mapping.sam }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW0U3/logs
# [2020-03-05 16:20:18.426] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-05 16:20:18.426] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-05 16:20:18.426] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-05 16:20:18.426] [jointLog] [info] parsing read library format
# [2020-03-05 16:20:18.426] [jointLog] [info] There is 1 library.
# [2020-03-05 16:20:18.512] [jointLog] [info] Loading pufferfish index
# [2020-03-05 16:20:18.513] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 34.459 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.1946 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 155.95 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 18.838 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 97.765 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 10.363 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 90.268 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 10.408 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 329.64 us
# -----------------------------------------
#
#
#
#
# [2020-03-05 16:20:18.777] [jointLog] [info] done
# [2020-03-05 16:20:18.777] [jointLog] [info] Index contained 37,708 targets
# [2020-03-05 16:20:18.792] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,001 fragments
# processed 1,500,001 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,001 fragments
# processed 8,000,000 fragments
# processed 8,500,001 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,001 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,001 fragments
# processed 17,500,000 fragments
# processed 18,000,002 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,001 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,001 fragments
# processed 24,500,001 fragments
# processed 25,000,000 fragments
# processed 25,500,001 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,001 fragments
# processed 27,500,000 fragments
# hits: 14,551; hits per frag:  0.000529316[2020-03-05 16:22:56.399] [jointLog] [info] Thread saw mini-batch with a maximum of 0.14% zero probability fragments
# [2020-03-05 16:22:56.407] [jointLog] [info] Thread saw mini-batch with a maximum of 0.12% zero probability fragments
# [2020-03-05 16:22:56.418] [jointLog] [info] Thread saw mini-batch with a maximum of 0.12% zero probability fragments
# [2020-03-05 16:22:56.447] [jointLog] [info] Thread saw mini-batch with a maximum of 0.12% zero probability fragments
# [2020-03-05 16:22:56.448] [jointLog] [error]
#
#
# [2020-03-05 16:22:56.448] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW7I2.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ validateMappings ] => { }
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { SR }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW7I2.fastq.gz }
# ### [ threads ] => { 4 }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW7I2 }
# ### [ writeMappings ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW7I2/mapping.sam }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW7I2/logs
# [2020-03-05 16:22:57.828] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-05 16:22:57.828] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-05 16:22:57.828] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-05 16:22:57.828] [jointLog] [info] parsing read library format
# [2020-03-05 16:22:57.828] [jointLog] [info] There is 1 library.
# [2020-03-05 16:22:57.911] [jointLog] [info] Loading pufferfish index
# [2020-03-05 16:22:57.911] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 33.483 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.2435 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 177.88 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 18.43 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 95.165 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 10.476 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 86.608 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 11.027 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 339.78 us
# -----------------------------------------
#
#
#
#
# [2020-03-05 16:22:58.169] [jointLog] [info] done
# [2020-03-05 16:22:58.169] [jointLog] [info] Index contained 37,708 targets
# [2020-03-05 16:22:58.185] [jointLog] [info] Number of decoys : 0
# processed 500,001 fragments
# processed 1,000,000 fragments
# processed 1,500,001 fragments
# processed 2,000,001 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,001 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,001 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,001 fragments
# processed 13,500,000 fragments
# processed 14,000,001 fragments
# processed 14,500,001 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,001 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,001 fragments
# processed 19,500,000 fragments
# processed 20,000,001 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# hits: 4,613,318; hits per frag:  0.192367[2020-03-05 16:25:02.940] [jointLog] [info] Thread saw mini-batch with a maximum of 0.38% zero probability fragments
# [2020-03-05 16:25:02.966] [jointLog] [info] Thread saw mini-batch with a maximum of 0.38% zero probability fragments
# [2020-03-05 16:25:02.966] [jointLog] [info] Thread saw mini-batch with a maximum of 0.34% zero probability fragments
# [2020-03-05 16:25:03.009] [jointLog] [info] Thread saw mini-batch with a maximum of 0.36% zero probability fragments
# [2020-03-05 16:25:03.009] [jointLog] [error]
#
#
# [2020-03-05 16:25:03.009] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW4I1.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ validateMappings ] => { }
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { SR }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW4I1.fastq.gz }
# ### [ threads ] => { 4 }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW4I1 }
# ### [ writeMappings ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW4I1/mapping.sam }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW4I1/logs
# [2020-03-05 16:25:04.401] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-05 16:25:04.401] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# ...
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.2114 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 166.85 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 16.729 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 97.925 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 11.739 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 85.44 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 10.728 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 341.99 us
# -----------------------------------------
#
#
#
#
# [2020-03-05 17:14:54.103] [jointLog] [info] done
# [2020-03-05 17:14:54.103] [jointLog] [info] Index contained 37,708 targets
# [2020-03-05 17:14:54.119] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,001 fragments
# processed 3,000,000 fragments
# processed 3,500,001 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,001 fragments
# processed 16,500,001 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,001 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,001 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# hits: 188,500; hits per frag:  0.00785686[2020-03-05 17:16:48.849] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-05 17:16:48.857] [jointLog] [info] Thread saw mini-batch with a maximum of 0.14% zero probability fragments
# [2020-03-05 17:16:48.884] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-05 17:16:48.934] [jointLog] [info] Thread saw mini-batch with a maximum of 0.14% zero probability fragments
# [2020-03-05 17:16:48.935] [jointLog] [error]
#
#
# [2020-03-05 17:16:48.935] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW3I3.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ validateMappings ] => { }
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { SR }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW3I3.fastq.gz }
# ### [ threads ] => { 4 }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW3I3 }
# ### [ writeMappings ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW3I3/mapping.sam }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW3I3/logs
# [2020-03-05 17:16:50.321] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-05 17:16:50.321] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-05 17:16:50.321] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-05 17:16:50.321] [jointLog] [info] parsing read library format
# [2020-03-05 17:16:50.321] [jointLog] [info] There is 1 library.
# [2020-03-05 17:16:50.402] [jointLog] [info] Loading pufferfish index
# [2020-03-05 17:16:50.402] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 32.256 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.1232 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 154.05 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 16.854 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 93.947 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 10.756 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 87.907 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 10.634 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 336.08 us
# -----------------------------------------
#
#
#
#
# [2020-03-05 17:16:50.657] [jointLog] [info] done
# [2020-03-05 17:16:50.657] [jointLog] [info] Index contained 37,708 targets
# [2020-03-05 17:16:50.672] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,001 fragments
# processed 9,500,001 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,001 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,001 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,001 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,001 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,001 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,000 fragments
# processed 30,000,001 fragments
# processed 30,500,000 fragments
# processed 31,000,001 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,001 fragments
# processed 33,500,001 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,001 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# processed 37,000,000 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# processed 38,500,000 fragments
# processed 39,000,000 fragments
# hits: 84,262; hits per frag:  0.00216124[2020-03-05 17:19:40.076] [jointLog] [info] Thread saw mini-batch with a maximum of 0.14% zero probability fragments
# [2020-03-05 17:19:40.113] [jointLog] [info] Thread saw mini-batch with a maximum of 0.14% zero probability fragments
# [2020-03-05 17:19:40.116] [jointLog] [info] Thread saw mini-batch with a maximum of 0.14% zero probability fragments
# [2020-03-05 17:19:40.141] [jointLog] [info] Thread saw mini-batch with a maximum of 0.14% zero probability fragments
# [2020-03-05 17:19:40.142] [jointLog] [error]
#
#
# [2020-03-05 17:19:40.142] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
# /home/jamila/jamila_Storage/data/expression_data/RW5I1.fastq.gz
# Version Info:   This is the most recent version of salmon.
# ### salmon (mapping-based) v1.1.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ validateMappings ] => { }
# ### [ index ] => { /home/jamila/jamila_Storage/data/genomic_resources/Puccinia_graminis_tritici_21-0.transcripts.fa.salmon.index }
# ### [ libType ] => { SR }
# ### [ unmatedReads ] => { /home/jamila/jamila_Storage/data/expression_data/RW5I1.fastq.gz }
# ### [ threads ] => { 4 }
# ### [ output ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW5I1 }
# ### [ writeMappings ] => { /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW5I1/mapping.sam }
# Logs will be written to /home/jamila/jamila_Storage/analyses/genes_expression/quant/RW5I1/logs
# [2020-03-05 17:19:41.592] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2020-03-05 17:19:41.592] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2020-03-05 17:19:41.592] [jointLog] [info] Usage of --validateMappings implies a default consensus slack of 0.2. Setting consensusSlack to 0.35.
# [2020-03-05 17:19:41.592] [jointLog] [info] parsing read library format
# [2020-03-05 17:19:41.592] [jointLog] [info] There is 1 library.
# [2020-03-05 17:19:41.672] [jointLog] [info] Loading pufferfish index
# [2020-03-05 17:19:41.672] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 31.742 ms
# -----------------------------------------
# size = 538160
# -----------------------------------------
# | Loading contig offsets | Time = 1.0468 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 137.76 us
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 17.319 ms
# -----------------------------------------
# size = 49426316
# Number of ones: 538159
# Number of ones per inventory item: 512
# Inventory entries filled: 1052
# -----------------------------------------
# | Loading contig boundaries | Time = 93.538 ms
# -----------------------------------------
# size = 49426316
# -----------------------------------------
# | Loading sequence | Time = 9.8223 ms
# -----------------------------------------
# size = 33281546
# -----------------------------------------
# | Loading positions | Time = 112.33 ms
# -----------------------------------------
# size = 51407184
# -----------------------------------------
# | Loading reference sequence | Time = 14.343 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 465.2 us
# -----------------------------------------
#
#
#
#
# [2020-03-05 17:19:41.953] [jointLog] [info] done
# [2020-03-05 17:19:41.953] [jointLog] [info] Index contained 37,708 targets
# [2020-03-05 17:19:41.975] [jointLog] [info] Number of decoys : 0
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,001 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,001 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,001 fragments
# processed 13,000,001 fragments
# processed 13,500,001 fragments
# processed 14,000,001 fragments
# processed 14,500,001 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,001 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,001 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,001 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,001 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,001 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,001 fragments
# processed 30,000,001 fragments
# processed 30,500,000 fragments
# processed 31,000,001 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,000 fragments
# processed 35,500,000 fragments
# processed 36,000,001 fragments
# processed 36,500,000 fragments
# processed 37,000,000 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# processed 38,500,000 fragments
# processed 39,000,000 fragments
# hits: 1,668,187; hits per frag:  0.0427941[2020-03-05 17:22:45.059] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-05 17:22:45.079] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-05 17:22:45.105] [jointLog] [info] Thread saw mini-batch with a maximum of 0.16% zero probability fragments
# [2020-03-05 17:22:45.156] [jointLog] [info] Thread saw mini-batch with a maximum of 0.18% zero probability fragments
# [2020-03-05 17:22:45.157] [jointLog] [error]
#
#
# [2020-03-05 17:22:45.157] [jointLog] [error] Processing reads : Error reading from the FASTA/Q stream. Minimum return code for left and right read was (-2). Make sure the file is valid.
